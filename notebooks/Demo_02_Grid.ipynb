# %% [markdown]
# # Demo 2: Grid

# %%
import sys
sys.path.append('..')
import loci as lc
from loci import io
from loci import index
from loci import plots
import geopandas as gpd
import numpy as np
import folium
# %matplotlib inline
import matplotlib

# %% [markdown]
# ## Create a GeoDataFrame from a CSV file containing POIs from OpenStreetMap in Berlin

# %%
pois = io.read_poi_csv(input_file='../datasets/osmpois-berlin.csv', target_crs='EPSG:3068')
print('Loaded ' + str(len(pois.index)) + ' POIs.')
# Out:
# b'Skipping line 22818: expected 5 fields, saw 6\nSkipping line 23991: expected 5 fields, saw 6\nSkipping line 25828: expected 5 fields, saw 6\nSkipping line 35946: expected 5 fields, saw 6\nSkipping line 35949: expected 5 fields, saw 7\nSkipping line 35951: expected 5 fields, saw 9\nSkipping line 43246: expected 5 fields, saw 6\nSkipping line 46730: expected 5 fields, saw 6\nSkipping line 48344: expected 5 fields, saw 6\nSkipping line 50558: expected 5 fields, saw 6\n'
# Loaded 53496 POIs.

# %%
pois.head()
# Out:
#           id                          name                 kwds  \
# 0  N29318897            U Kurfürstenstraße  [transport, subway]
# 1  N29324017  U Mendelssohn-Bartholdy-Park  [transport, subway]
# 2  N29334078                  Abschnitt 26    [amenity, police]
# 3  N29334080                 Schmargendorf        [poi, suburb]
# 4  N29336704                Charlottenburg        [poi, suburb]
#
#                                       geometry
# 0  POINT (22106.32722588773 19231.82318284977)
# 1  POINT (22991.86532023628 19671.37924249026)
# 2   POINT (18263.1507574199 17661.79288238728)
# 3  POINT (17413.86949738537 16912.28004474215)
# 4   POINT (18565.6226327344 21007.13288168284)

# %% [markdown]
# ## Create grid

# %%
g, gwidth, gheight = lc.index.grid(pois, cell_size_ratio=0.05)
g.head()
# Out:
#          cell_id  cell_x  cell_y  score  \
# cell_id
# 169          169       8       9   1125
# 128          128       6       8    464
# 130          130       6      10    820
# 110          110       5      10    199
# 129          129       6       9   1500
#
#                                                   contents  \
# cell_id
# 169      [N29318897, N29324017, N29495049, N29495891, N...
# 128      [N29334078, N29334080, N26739106, N26739124, N...
# 130      [N29336704, N27409122, N29123762, N29123763, N...
# 110      [N29336705, N27587012, N27587041, N29123761, N...
# 129      [N29336992, N29833425, N29833491, N29997723, N...
#
#                                                   geometry
# cell_id
# 169      POLYGON ((23529.69626294084 18483.70797981274,...
# 128      POLYGON ((18822.66325503924 16511.99699755674,...
# 130      POLYGON ((18822.66325503924 20455.41896206874,...
# 110      POLYGON ((16469.14675108844 20455.41896206874,...
# 129      POLYGON ((18822.66325503924 18483.70797981274,...

# %% [markdown]
# ## Visualize the grid on the map

# %%
plots.map_grid(g, percentiles=(0.5, 0.8, 0.9, 0.95, 0.98, 0.99), opacity=0.7)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
